# %% [markdown]
# # Sample Report:
#
# #### McAuliffe, P. F. et al. "Ability to generate patient-derived breast cancer xenografts is enhanced in chemoresistant disease and predicts poor patient outcomes". PLoS ONE 10, e0136851 (2015)
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4556673/pdf/pone.0136851.pdf

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# ## 1. Acquire Data

# %% [markdown]
# ### S2 Table

# %%
# Differentially expressed proteins between patients(P0) and mice (P1)
df = pd.read_excel(r'BCX_tables/S2_Table.xlsx')
df.head()
# Out:
#   S2 Table: Differentially expressed proteins between P0 and P1, cutoff: FDR=0.2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               EGFR
# 4                                         Merlin/NF2
#
#        Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0             NaN        NaN        NaN            NaN        NaN        NaN
# 1  Paired t tests        NaN        NaN  P0 (Patients)        NaN  P1 (Mice)
# 2    T statistics    P value        FDR           mean         sd       mean
# 3         -8.3362     0.0011     0.0662        -0.4167     0.7898     1.5519
# 4          5.4049     0.0057     0.0713        -0.2657     0.2003    -0.8749
#
#   Unnamed: 7
# 0        NaN
# 1        NaN
# 2         sd
# 3     0.7004
# 4      0.228

# %% [markdown]
# ### S3 Table

# %%
# Copy number alterations detected in all tested passages of six models by targeted exome sequencing (BCX-006, -010, -011, 017, -022, -024) 
# High amplification cutoff was 4 (highlighted in red) and high deletion cutoff was 1 (highlighted in green) in excel
df = pd.read_excel(r'BCX_tables/S3_Table.xlsx')
df.head()
# Out:
#   S3 Table. Copy number alterations detected in all tested passages of six models by targeted exome sequencing.  \
# 0                                                NaN
# 1                                            BCX-006
# 2                                               AKT1
# 3                                                 AR
# 4                                               ATRX
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         P0         P1         P4         P7        P10        P13
# 2          4        NaN        NaN        NaN        NaN        NaN
# 3          1        1.3        1.1        1.1        0.9          1
# 4          1        0.9        1.1        1.1        0.9          1
#
#   Unnamed: 7  Unnamed: 8 Unnamed: 9  ... Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 0        NaN         NaN        NaN  ...         NaN         NaN         NaN
# 1        P16         NaN    BCX-010  ...         NaN     BCX-022          P0
# 2        NaN         NaN        ATM  ...         NaN       AKAP3         3.2
# 3          1         NaN      CSMD1  ...         NaN         ATM         0.5
# 4          1         NaN   HEATR7B2  ...         NaN       BRCA2         1.2
#
#   Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  Unnamed: 37 Unnamed: 38  \
# 0         NaN         NaN         NaN         NaN          NaN         NaN
# 1          P1          P6         NaN     BCX-024           P0          P1
# 2         9.7         8.8         NaN        BAP1          1.5         0.7
# 3         0.5         0.9         NaN      CDKN2A          2.8           4
# 4           1         1.4         NaN      CPAMD8          NaN         3.1
#
#   Unnamed: 39
# 0         NaN
# 1          P7
# 2         1.4
# 3         5.6
# 4           5
#
# [5 rows x 40 columns]

# %% [markdown]
# ### S4 Table

# %%
# Copy number alterations detected in P0 and P1 of four models by whole exome sequencing (BCX-010, -017, -022, -024)
# High amplification cutoff was 4 (highlighted in red) and high deletion cutoff was 1 (highlighted in green) in excel
df = pd.read_excel(r'BCX_tables/S4_Table.xlsx')
df.head()
# Out:
#   S4 Table. Copy number alterations detected in P0 and P1 of four models by whole exome sequencing.  \
# 0                                                NaN
# 1                                            BCX-010
# 2                                               Gene
# 3                                            - Q151L
# 4                                           ADAM17 -
#
#   Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN         NaN        NaN        NaN        NaN
# 1        NaN        NaN         NaN    BCX-017        NaN        NaN
# 2         P0         P1         NaN       Gene         P0         P1
# 3     0.3561     0.4835         NaN          -     0.0639        NaN
# 4     0.0505        NaN         NaN     AMPH -     0.1136        NaN
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  Unnamed: 11  \
# 0         NaN        NaN        NaN         NaN          NaN
# 1         NaN    BCX-022        NaN         NaN          NaN
# 2         NaN       Gene         P0          P1          NaN
# 3         NaN     - C29S     0.4615         NaN          NaN
# 4         NaN          -     0.3444      0.4485          NaN
#
#            Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0                  NaN         NaN         NaN
# 1              BCX-024         NaN         NaN
# 2                 Gene          P0          P1
# 3  2015-03-04 00:00:00      0.2105        0.35
# 4              - M110T      0.0627         NaN

# %% [markdown]
# ### S5 Table

# %%
# Somatic mutations detected in P0 and P1 of four models by whole exome sequencing (BCX-010, -017, -022, -024)
df = pd.read_excel(r'BCX_tables/S5_Table.xlsx')
df.head()
# Out:
#   S5 Table. Somatic mutations detected in P0 and P1 of four models by whole exome sequencing.  \
# 0                                                NaN
# 1                                            BCX-006
# 2                                       CSMD2 R2096K
# 3                                         NAV3 D414G
# 4                                      PIK3CA H1047R
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1         P0         P1         P4         P7        P10        P13
# 2       5.53        NaN        NaN        NaN        NaN        NaN
# 3      28.01      41.79      29.22      29.19      35.45      31.38
# 4      16.31      24.91      22.38      20.31      30.25      30.77
#
#   Unnamed: 7  Unnamed: 8   Unnamed: 9  ... Unnamed: 30     Unnamed: 31  \
# 0        NaN         NaN          NaN  ...         NaN             NaN
# 1        P16         NaN      BCX-010  ...         NaN         BCX-022
# 2        NaN         NaN  EGFR D1072E  ...         NaN  SMARCA4 R1465G
# 3      35.05         NaN  FGFR1 V273M  ...         NaN      TP53 E221*
# 4      31.75         NaN    MET V486A  ...         NaN      MLL3 S784Y
#
#   Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35  \
# 0         NaN         NaN         NaN         NaN
# 1          P0          P1          P6         NaN
# 2       44.84       40.73        48.1         NaN
# 3       96.71       70.12       98.43         NaN
# 4         NaN        8.83        8.19         NaN
#
#                     Unnamed: 36  Unnamed: 37 Unnamed: 38 Unnamed: 39
# 0                           NaN          NaN         NaN         NaN
# 1                       BCX-024           P0          P1          P7
# 2                   ERCC5 P903S        21.42         NaN         NaN
# 3                   FAT3 K2447N         5.59         NaN         NaN
# 4  FGFR4 (splice donor variant)        29.05         NaN         NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### S6 Table

# %%
# Somatic mutations detected in all tested passages of six models by targeted exome sequencing (BCX-006, -010, -011, 017, -022, -024)
df = pd.read_excel(r'BCX_tables/S6_Table.xlsx')
df.head()
# Out:
#   S6 Table. Somatic mutations detected in all tested passages of six models by targeted exome sequencing.  \
# 0                                                NaN
# 1                                         BCX-010-P0
# 2                                               gene
# 3                                2015-09-02 00:00:00
# 4                                2015-09-03 00:00:00
#
#    Unnamed: 1 Unnamed: 2           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN        NaN                  NaN        NaN        NaN
# 1         NaN        NaN           BCX-010-P1        NaN        NaN
# 2         CNS         CN                 gene        CNS         CN
# 3         DEL        1.2  2015-09-02 00:00:00      H.DEL          1
# 4  H.AMP,NORM      4,2.5  2015-09-03 00:00:00  H.AMP,AMP      4.8,3
#
#    Unnamed: 6           Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0         NaN                  NaN        NaN        NaN  ...
# 1         NaN           BCX-017-P0        NaN        NaN  ...
# 2         NaN                 gene        CNS         CN  ...
# 3         NaN  2015-03-03 00:00:00        DEL        1.5  ...
# 4         NaN                  NaN        NaN        NaN  ...
#
#            Unnamed: 17 Unnamed: 18 Unnamed: 19  Unnamed: 20  \
# 0                  NaN         NaN         NaN          NaN
# 1           BCX-022-P1         NaN         NaN          NaN
# 2                 gene         CNS          CN          NaN
# 3  2015-03-01 00:00:00       H.DEL         0.7          NaN
# 4  2015-03-02 00:00:00       H.DEL         0.8          NaN
#
#            Unnamed: 21   Unnamed: 22            Unnamed: 23  \
# 0                  NaN           NaN                    NaN
# 1           BCX-024-P0           NaN                    NaN
# 2                 gene           CNS                     CN
# 3  2015-03-05 00:00:00       AMP,DEL                3.5,1.4
# 4              5S_rRNA  DEL,NORM,AMP  1.5,2.1,3,2.2,2.9,2.3
#
#            Unnamed: 24     Unnamed: 25                  Unnamed: 26
# 0                  NaN             NaN                          NaN
# 1           BCX-024-P1             NaN                          NaN
# 2                 gene             CNS                           CN
# 3  2015-03-05 00:00:00           H.DEL                          0.7
# 4              5S_rRNA  H.DEL,AMP,NORM  0.8,2.8,1.9,2.9,2.1,3.4,2.2
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 2. Prepare Data

# %%
# Filter NaNs 
# Label "Unnamed" columns
# Clean data

# %% [markdown]
# ## 3. Explore Relationships

# %% [markdown]
# ## 4. Model (ML)

# %% [markdown]
# ## 5. Conclusions
